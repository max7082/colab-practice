# %% [markdown]
# <a href="https://colab.research.google.com/github/max7082/colab-practice/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Numpy**

# %%
import numpy as np
import time

# %% [markdown]
# NumPy에서 제공되는 np.dot()함수와 직접 구현 함수의 속도 비교

# %%
def vec_vec_mul_func(vec_x, vec_y):
  total=0
  for row in range(len(vec_x)):
    total+=vec_x[row]*vec_y[row]
  return total

# %%
a=np.ones(10000)
b=np.ones(10000)
x = a.tolist()
y = b.tolist()
print(vec_vec_mul_func(x,y))
# Out:
# 10000.0

# %%
def mat_vec_mul_func(mat_A, vec_x):
  result=[]
  for row in mat_A:
    total=0
    for col in range(len(row)):
      total+=row[col]*vec_x[col]
    result.append(total)
  return result

# %%
a = np.ones((1000, 1000))
b = np.ones(1000)
x = a.tolist()
y = b.tolist()
print(mat_vec_mul_func(x,y))
# Out:
# [1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.
# ...

# %%
def mat_mat_mul_func(mat_A, mat_B):
  result_mat=[]
  for row in mat_A:
    result_row=[]
    for col in range(len(mat_B[0])):
      total=0
      for i in range(len(row)):
        total+=row[i]*mat_B[i][col]
      result_row.append(total)
    result_mat.append(result_row)
  return result_mat

# %%
a = np.ones((100, 100))
b = np.ones((100, 100))
x = a.tolist()
y = b.tolist()
print(mat_mat_mul_func(x,y))
# Out:
# [[100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0], [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 
# ...

# %%
a=np.ones(10000)
b=np.ones(10000)
x = a.tolist()
y = b.tolist()
start = time.time()
np.dot(a, b)
end = time.time()
print("NumPy", end - start)
start = time.time()
vec_vec_mul_func(x, y)
end = time.time()
print("직접 구현:", end - start)
# Out:
# NumPy 0.0005495548248291016
# 직접 구현: 0.0014140605926513672

# %%
a = np.ones((1000, 1000))
b = np.ones(1000)
x = a.tolist()
y = b.tolist()
start = time.time()
np.dot(a, b)
end = time.time()
print("NumPy:", end - start)

start = time.time()
mat_vec_mul_func(x, y)
end = time.time()
print("직접 구현:", end - start)
# Out:
# NumPy: 0.0018334388732910156
# 직접 구현: 0.1129615306854248

# %%
a = np.ones((100, 100))
b = np.ones((100, 100))
x = a.tolist()
y = b.tolist()
start = time.time()
np.dot(a, b)
end = time.time()
print("NumPy:", end - start)
start = time.time()
mat_mat_mul_func(x, y)
end = time.time()
print("직접 구현:", end - start)
# Out:
# NumPy: 0.0005648136138916016
# 직접 구현: 0.15378117561340332

# %% [markdown]
# 실행 시간을 비교한 결과 모두 NumPy 방식이 직접구현 방식보다 짧은 시간이 걸렸다.
