# %% [markdown]
# <a href="https://colab.research.google.com/github/max7082/colab-practice/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
a=torch.tensor([2.0])
weights = [
    torch.tensor([i], dtype=torch.float32, requires_grad=True)
    for i in (1, 2, 3, 2)
]
w1, w2, w3, w4 = weights
b = w1 * a
c = w2 * a
d = w4 * b + w3 * c
loss = (15 - d) ** 2
loss.backward()
print("예측값:", d.item())
print("손실:", loss.item())
print("w1의 기울기:", w1.grad.item())
print("w2의 기울기:", w2.grad.item())
print("w3의 기울기:", w3.grad.item())
print("w4의 기울기:", w4.grad.item())
# Out:
# 예측값: 16.0
# 손실: 1.0
# w1의 기울기: 8.0
# w2의 기울기: 12.0
# w3의 기울기: 8.0
# w4의 기울기: 4.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
